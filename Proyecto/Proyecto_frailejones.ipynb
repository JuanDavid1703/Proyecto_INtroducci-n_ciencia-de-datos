# %% [markdown]
# # Clasificación de especies de frailejón en el sector del páramo del Sumapaz a través de la morfología foliar
#
# ##Comprensión del negocio
#
# ###Individuos claves de la organización
# Estudiantes de PEAMA, representantes del Jardín Botánico, de conservación de parque e Ivan Jiménez integrante de Missouri Botanical Garden.
#
# ##Problemática general
#
# <img title="Páramo" src="https://github.com/JuanDavid1703/Proyecto_INtroducci-n_ciencia-de-datos/raw/main/Proyecto/Imagenes/Paramo.jpg" width="500">
#
#
# Las especies a menudo se consideran unidades básicas de diversidad biológica en ecología, evolución, biogeografía y biología de la conservación (Cardenas 2016); la intervención de la mano del hombre y el cambio climático global está afectando el ecosistema de los páramos en Colombia y en general del territorio suramericano, esto está generando que un familia de plantas que tiene gran predominio en estos terrenos y que  además sirven como interceptación y retención del agua en el suelo, que tienen funciones como la evapotranspiración y la retención del carbono orgánico en el suelo,  la espeletia o mayormente conocida como frailejón está teniendo una transformación de características debido al cambio de los pisos térmicos y al ser tan dependiente del hábitat en que se encuentra, un cambio en su ecosistema podría acarrear la extinción de ella.
#
# <img title="Pisos térmicos" src="https://github.com/JuanDavid1703/Proyecto_INtroducci-n_ciencia-de-datos/raw/main/Proyecto/Imagenes/Pisostermicos.jpg" width="350">
#
#
# La necesidad de distinguir el ecosistema en donde se trabaja genera la necesidad de identificar las diferentes especies que componen el ecosistema, para el estudio de caso, dado el predominio de la espeletia en los páramos, es de gran importancia identificar esas diferentes especies.
#
# Existen varios métodos de identificación tanto fenotípica como genotípica, la finalidad de este documento es presentar un método de identificación fenotípica a través de la caracterización de las hojas de cada planta.
#
# Existe una gran variedad en tipos de hojas, esto debido a las formas, bordes y  tipo de venación  que existen en cada una de ellas, la distinción de cada tipo permite aportar a una mejor  clasificación taxonómica de las plantas.
#
#
# <img src="https://github.com/JuanDavid1703/Proyecto_INtroducci-n_ciencia-de-datos/raw/main/Proyecto/Imagenes/1200px-Leaf_morphology_es.png" width="350">
#
#
# ##Definición de objetivos y criterios de éxito
#
# **Objetivo Comercial**
#
# Como objetivo comercial se tiene la optimización del tiempo y/o dinero en el proceso de identificación de especies de frailejón por medio de métodos ya sean fenotíicos o genotípico ya preestablecidos.
#
# *Criterio de éxito*
#
# Disminuición del tiempo y/o el dinero en un porcentaje x%.
#
# **Objetivo en torno a los datos**
#
# Como objetivo técnico se tiene la creación de una máquina clasificadora que identifique entre tres especies del páramo de sumapaz mediante la morfología foliar.
#
# *Criterio de éxito*
#
# Precisión del clasificados mayor al 0.8
#
#
# ##Evaluación de la situación
# **Riesgos:**
#
# * La calidad de las imágenes no permitan tener una buena caracterización de las imágenes.
# * Las características morfológicas no sean suficientes para distinguir cada tipo de planta además.
# * El desbalance de la proporción de los datos teniendo más imágenes  de las especie Summapacis.
# * La cantidad de datos sean suficientes para alimentar el modelo que se vaya a implementar
#
# **Resticciones**
#
# * Este estudio se realizará solo para especies del páramo del Sumapaz, sin embrago es posible aplicarlo a otros tipos de especies de frailejón.
# * La necesitdad del buen tratamiento de las hojas en el almacenamiento y el acarreo.
# * Tener una buena calidad en la toma de las fotografías.
#
# **Beneficios y costos**
#
# Como beneficio del estudio, el tiempo necesario para realizar esto manualmente se reducirá en un alto porcentaje, será una ayuda para los especialistas en fuutras investigaciones
#
# Como costos el tiempo necesario para aplicar el modelo y la limpieza de las imágenes  para la extracción de características de las hojas
#
# **Datos:**
#
# Los datos consisten en 180 imágenes de hojas de frailejones de diferentes tamaños en 4 diferentes capas de colores, estas fueron obtenidas mediante fotografías tomadas en el páramo del Sumapaz (Jimenez 2020), cada fotografía tenía en promedio de 3 a 4 hojas de frailejón.
#
# En este estudio se realizará un análisis de la morfología de las hojas en diferentes medidas y tamaños. A cada imagen se le realizará la separación de la hoja con le fondo, algo necesario para poder aplicar el algortimo deseado en la estracción de características de contorno y características básicas, una pequeña muestra se puede observar en la imagen
#
# <img src="https://github.com/JuanDavid1703/Proyecto_INtroducci-n_ciencia-de-datos/raw/main/Proyecto/Imagenes/primicia.jpg" width="500">
#
#
#
# #Bibliografía
#
# [1] ***Pineda Yam, Cortés Andrés, Madriñán Santiago, Jiménez Iván***, " *The Nature of Espeletia Species* ", 2020.
#
# [2] ***M. F. Cárdenas Agudelo***, "*Ecohydrology of paramos in Colombia: Vulnerability to climate change and land use*", Universidad Nacional de Colombia 2016.
#
# [3] ***José Cuatrecasas***, "*A systematic study of the subtribe Espeletiinae* ", The New York Botanical Garden Press.
#
# [4] ***Leonel Olivares, Jorge Victorino, Francisco Gómez***, "*Automatic Leaf Shape Category Discovery*", Universidad Central, 2016.

# %% [markdown]
# #IDA

# %% [markdown]
# ##Resumen de configuración de los datos:
# Los datos consisten en 180 imágenes de hojas de frailejones de diferentes tamaños en 4 diferentes capas de colores, estas fueron obtenidas mediante fotografías tomadas en le páramo del Sumapaz, cada fotografía tenía en promedio de 3 a 4 hojas de frailejón.
#
# De estos datos se desea realizar una apropiada clasificación de especies de frailejones mediante la caracterización y clasificación de hojas de frailejón usando morfología foliar.
#
# Como primicia se quizo reconocer los tipos de datos que se tenían, para ello se debió separar las hojas del fondo de cada fotografía, en este proceso se usó "Adobe photshop express", programa que fue escogido después de intentar con varios, una de las más fuertes complicaciones en la separación de las hojas del fondo se debía a la calidad de la iluminación de cada imagen, como no se tenía buena iluminación, no se pudieron separar todas las hojas de todas las imágenes, se lograron obtener 314 hojas de frailejón separadas y en su mayoría bien contrastadas con su fondo, la proporción que hay de cada especie morfológicamente escogida se prsenta en siguiente diagrama.
#
# ![image.png](data:image/png;base64,...)
#
# Después de esto, la intención es obtener características que permitan distinguir cada hoja, las primeras características que se obtienen están relacionadas con la geometría básica de una elipse, dado que son figuras cerradas es posible contrastar cada hoja con una posible elipse con características distinguibles entre ellas, hubo algunos inconvenientes dada la separación realizada del fondo en cada hoja ya que algo de ruido se mezcló en algunas imágenes, por esto se tuvo que proceder en realizar una limpieza exhaustiva y además arreglar las tonalidades del color de cada imagen.
#
#
# Depués de haber obtenido con éxito los contornos se procedió a hallar características básicas elípticas de cada hoja, las características escojidas fueron:
#
# * El área
# * El perímetro
# * Las medidas de los ejes axiales, el mayor y el menor.
# * La medida del eje focal
#
# A partir de las anteriores características se obtuvieron los siguientes descriptores:
#
# $\begin{align*}
# R_{1}=&\frac{Perimetro}{Area}\\
# R_{2}=&\frac{Eje_{menor}}{Eje_{mayor}}\\
# R_{3}=&\frac{Eje_{mayor}}{Perimetro}\\
# R_{4}=&\frac{Eje_{menor}}{Perimetro}\\
# R_{5}=&\frac{\sqrt{Eje_{mayor}^2-Eje_{menor}^2}}{Perimetro}\\
# \end{align*}$
#
#
# Las anteiores características fueron escogidas dado que cada hoja se puede encerrar en una elipse que está caracterizada por ciertos parámetros, esto nos permitiría representar mejor cada hoja de frailejón, además como otra medida, al usar los contornos se pueden identificar las curvas que representan cada componenete del conjunto de puntos como se ve en la imagen siguiente:
#
# <img title="Páramo" src="https://github.com/JuanDavid1703/Proyecto_INtroducci-n_ciencia-de-datos/raw/main/Proyecto/Imagenes/contorno.png" width="1000">
#
# La descripción general de los datos básicos de la muestra se puede observar a través de las características obtenidas mencionados anteriormente, los datos obtenidos se presentan en la siguiente tabla, como se puede ver son valores entre 0 y uno, además como son razónes es posible quitar las unidades de medida de cada imágen teniendo solamente proporciones para distinguir las hojas:
#
#
# <img title="Páramo" src="https://github.com/JuanDavid1703/Proyecto_INtroducci-n_ciencia-de-datos/raw/main/Proyecto/Imagenes/Tabla_inicial.png" width="600">
#
#
# La matriz de correlación entre cada par de datos se puede observar en la siugiente figura, los resultados obtenidos se deben a la variación de las dimensiones de las imágenes analizadas
#
# <img title="Páramo" src="https://github.com/JuanDavid1703/Proyecto_INtroducci-n_ciencia-de-datos/raw/main/Proyecto/Imagenes/Distri_basicas.png" width="1300" height="800">
#
#
#
# **Conclusiones**:
#
# Dada la estracción de las características mostradas anteriormente se puede crear el espacio de características el cual servirá para realizar la respectivo tratamiento de los datos usando diferentes métodos de clasificación para obtener una buen distinción entre cada especie, este es el objetivo del proyecto.
